# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\mhtan\Desktop\csvfolder\price_predictions.csv")
print("shape of dataset")
print(df.shape)
# Out:
# shape of dataset
# (43, 3)

# %%
print("first 5 rows")
print(df.head())
# Out:
# first 5 rows
#          Date       Actual  Predicted
# 0  2025-12-02  4186.600098  4262.7290
# 1  2025-12-03  4199.299805  4275.6733
# 2  2025-12-04  4211.799805  4288.8400
# 3  2025-12-05  4212.899902  4301.7480
# 4  2025-12-08  4187.200195  4313.2720

# %%
print("dataset info")
print(df.info())
# Out:
# dataset info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       43 non-null     object
#  1   Actual     43 non-null     float64
#  2   Predicted  43 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.1+ KB
# None
